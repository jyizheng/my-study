# %% [markdown]
# <a href="https://colab.research.google.com/github/jyizheng/my-study/blob/main/kClosestPointsToOrigin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import heapq
class Solution:
    def kClosest(self, points: List[List[int]], k: int) -> List[List[int]]:
        hq = []
        #hq = heapq.heapify(array)
        for i in range(k):
            p = points[i]
            print(f" insert p={p}")
            dist = -math.sqrt(p[0]**2 + p[1]**2)
            heapq.heappush(hq, (dist, p))

        for p in points[k:]:
            #print(f" insert2 p={p}")
            dist =  -math.sqrt(p[0]**2 + p[1]**2)
            print(f"{dist}, {hq[0][0]}")
            if dist > hq[0][0]:
                res = heapq.heappop(hq)
                print(f"replace {res} with p={dist},{p}")
                heapq.heappush(hq, (dist, p))
        res = []
        while hq:
            d, p = heapq.heappop(hq)
            res.append(p)

        return res
